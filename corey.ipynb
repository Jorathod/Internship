# %%
import requests
from bs4 import BeautifulSoup

# %%
a="https://www.patreon.com/coreyms"
page=requests.get(a)
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html><head><meta charset="utf-8"/><script type="text/javascript">
#             window.patreonConfig = {"apiServer":"www.patreon.com/api","nionDisableDefaultIncludes":true,"formattingLocale":"en-US","eventLoggingPlatform":"Web","isWebView":false,"pathname":"/\u003cstring:campaign_identifier\u003e","is_impersonating":false,"csrfSignature":"Ydhjxy3nPY3e6B8_bYCU-8IWj18gsbwJV6xdaL3iUYk"};
# ...

# %%
div=soup.find("div",class_="sc-xg7a7d-0 jJOVvL")
print(div.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 2
#       1 div=soup.find("div",class_="sc-xg7a7d-0 jJOVvL")
# ----> 2 print(div.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
heading=soup.find_all("div",class_="sc-137kp8k-1 lbjiyO")
heading
# Out:
# []
